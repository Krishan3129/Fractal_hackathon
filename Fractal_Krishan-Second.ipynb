# %%
import pandas as pd
import re
path = r"C:\Users\Krishan\Downloads\d6eb5cd1b3b211ef\Dataset\train.csv"

data = pd.read_csv(path)

print(data.head())
# Out:
#    Index                                                 ph  \
# 0      0  <p>😅The pH value observed is:  0.2644088544860...
# 1      1  <p>😇The solution's pH level is  0.012034498894...
# 2      2  <br>😀The pH reading measures 0.491167423175516...
# 3      3  <h1>😅The water sample's pH level is  0.4865531...
# 4      4  <p>😍The observed pH value of  0.07548804288855...
#
#                                             Hardness  \
# 0  <br>😒With a hardness level of  2.6735383052025...
# 1  <h1>😀The water hardness is measured at  2.6303...
# 2  <h2>😅With a hardness level of  1.2213782428674...
# 3  <h2>😀With a hardness level of  1.2591335755542...
# 4  <p>😁With a hardness level of  1.65681755735377...
#
#                                               Solids  Chloramines   Sulfate  \
# 0  <br>😅The water sample exhibits a total solids ...     1.431972  1.303685
# 1  <br>😒The total solids content in the sample is...     0.911372  1.181754
# ...

# %%
# Create DataFrame
df = pd.DataFrame(data)

# Function to extract numeric value and classification for pH
def extract_ph_info(text):
    numeric_match = re.search(r"\b\d+\.\d+\b", text)
    numeric_value = float(numeric_match.group()) if numeric_match else None
    if "acidic" in text.lower():
        description = "0"
    elif "neutral" in text.lower():
        description = "1"
    elif "alkaline" in text.lower():
        description = "2"
    else:
        description = "4"
    return pd.Series([numeric_value, description])

# Function to extract numeric value and classification for Hardness
def extract_hardness_info(text):
    numeric_match = re.search(r"\b\d+\.\d+\b", text)
    numeric_value = float(numeric_match.group()) if numeric_match else None
    if "soft" in text.lower():
        description = "0"
    elif "moderate" in text.lower():
        description = "1"
    elif "hard" in text.lower():
        description = "2"
    elif "moderately hard" in text.lower():
        description = "3"
    else:
        description = "4"
    return pd.Series([numeric_value, description])

# Function to extract numeric value and classification for Solids
def extract_solids_info(text):
    numeric_match = re.search(r"\b\d+\.\d+\b", text)
    numeric_value = float(numeric_match.group()) if numeric_match else None
    if "low" in text.lower():
        description = "0"
    elif "moderate" in text.lower():
        description = "1"
    elif "concentrated" in text.lower():
        description = "2"
    else:
        description = "3"
    return pd.Series([numeric_value, description])

# Function to extract numeric value and classification for Turbidity
def extract_turbidity_info(text):
    numeric_match = re.search(r"\b\d+\.\d+\b", text)
    numeric_value = float(numeric_match.group()) if numeric_match else None
    if "cloudy" in text.lower():
        description = "0"
    elif "clear" in text.lower():
        description = "1"
    elif "suspended particles" in text.lower():
        description = "2"
    else:
        description = "3"
    return pd.Series([numeric_value, description])

# Apply the extraction functions to each column and create new columns
df[['pH_value', 'pH_description']] = df['ph'].apply(extract_ph_info)
df[['Hardness_value', 'Hardness_description']] = df['Hardness'].apply(extract_hardness_info)
df[['Solids_value', 'Solids_description']] = df['Solids'].apply(extract_solids_info)
df[['Turbidity_value', 'Turbidity_description']] = df['Turbidity'].apply(extract_turbidity_info)

# Display the updated DataFrame
print(df)
# Out:
#       Index                                                 ph  \
# 0         0  <p>😅The pH value observed is:  0.2644088544860...
# 1         1  <p>😇The solution's pH level is  0.012034498894...
# 2         2  <br>😀The pH reading measures 0.491167423175516...
# 3         3  <h1>😅The water sample's pH level is  0.4865531...
# 4         4  <p>😍The observed pH value of  0.07548804288855...
# ...     ...                                                ...
# 9995   9995  <br>😍The observed pH value of  0.0666474523593...
# 9996   9996  <p>😀The observed pH value of  0.87789992053641...
# 9997   9997  <h1>😇The water sample's pH level is  0.0547191...
# 9998   9998  <h1>😒The solution's pH level is  0.86477809896...
# 9999   9999  <p>😍The water sample's pH level is  0.69271759...
#
#                                                Hardness  \
# 0     <br>😒With a hardness level of  2.6735383052025...
# 1     <h1>😀The water hardness is measured at  2.6303...
# ...

# %%
df.head()
# Out:
#    Index                                                 ph  \
# 0      0  <p>😅The pH value observed is:  0.2644088544860...
# 1      1  <p>😇The solution's pH level is  0.012034498894...
# 2      2  <br>😀The pH reading measures 0.491167423175516...
# 3      3  <h1>😅The water sample's pH level is  0.4865531...
# 4      4  <p>😍The observed pH value of  0.07548804288855...
#
#                                             Hardness  \
# 0  <br>😒With a hardness level of  2.6735383052025...
# 1  <h1>😀The water hardness is measured at  2.6303...
# 2  <h2>😅With a hardness level of  1.2213782428674...
# 3  <h2>😀With a hardness level of  1.2591335755542...
# 4  <p>😁With a hardness level of  1.65681755735377...
#
#                                               Solids  Chloramines   Sulfate  \
# 0  <br>😅The water sample exhibits a total solids ...     1.431972  1.303685
# 1  <br>😒The total solids content in the sample is...     0.911372  1.181754
# ...

# %%
df.drop(columns=["Index","ph","Hardness","Solids","Turbidity"], inplace = True)

# %%
df.head()
# Out:
#    Chloramines   Sulfate  Conductivity  Organic_carbon  Trihalomethanes  \
# 0     1.431972  1.303685      1.563001        0.697062         2.010126
# 1     0.911372  1.181754      1.741640        0.896108         1.807786
# 2     1.506492  1.700871      2.322337        1.035440         1.548768
# 3     2.658852  3.035266      2.409255        1.185713         1.232375
# 4     2.169616  1.520531      1.990604        1.237182         1.589307
#
#    Potability  pH_value pH_description  Hardness_value Hardness_description  \
# 0    1.252351  0.264409              2        2.673538                    2
# 1    1.124565  0.012034              2        2.630323                    1
# 2    0.525886  0.491167              2        1.221378                    2
# 3    0.715288  0.486553              4        1.259134                    2
# 4    0.890722  0.075488              0        1.656818                    2
#
#    Solids_value Solids_description  Turbidity_value Turbidity_description
# ...

# %%
df.head()
# Out:
#    Chloramines   Sulfate  Conductivity  Organic_carbon  Trihalomethanes  \
# 0     1.431972  1.303685      1.563001        0.697062         2.010126
# 1     0.911372  1.181754      1.741640        0.896108         1.807786
# 2     1.506492  1.700871      2.322337        1.035440         1.548768
# 3     2.658852  3.035266      2.409255        1.185713         1.232375
# 4     2.169616  1.520531      1.990604        1.237182         1.589307
#
#    Potability  pH_value pH_description  Hardness_value Hardness_description  \
# 0    1.252351  0.264409              2        2.673538                    2
# 1    1.124565  0.012034              2        2.630323                    1
# 2    0.525886  0.491167              2        1.221378                    2
# 3    0.715288  0.486553              4        1.259134                    2
# 4    0.890722  0.075488              0        1.656818                    2
#
#    Solids_value Solids_description  Turbidity_value Turbidity_description
# ...

# %%
path = r"C:\Users\Krishan\Downloads\d6eb5cd1b3b211ef\Dataset\test.csv"

data1 = pd.read_csv(path)

print(data1.head())
# Out:
#    Index                                                 ph  \
# 0  10000  <br>😒The observed pH value of  0.4583260930518...
# 1  10001  <br>😀The pH value observed is:  0.006163832801...
# 2  10002  <h2>😀The pH reading measures 0.682188913921691...
# 3  10003  <p>😀The observed pH value of  0.56282397372454...
# 4  10004  <h1>😇The pH reading measures 0.336142283595807...
#
#                                             Hardness  \
# 0  <h1>😁The observed water hardness of  1.7903445...
# 1  <p>😁The observed water hardness of  2.37971669...
# 2  <h2>😇The observed water hardness of  1.4080275...
# 3  <br>😀The observed water hardness of  1.8369703...
# 4  <h1>😀The water hardness is measured at  1.5104...
#
#                                               Solids  Chloramines   Sulfate  \
# 0  <p>😁Observing a solids concentration of  1.573...     1.540880  1.659576
# 1  <h1>😒The total solids content in the sample is...     1.225821  1.320635
# ...

# %%
# Create DataFrame
df1 = pd.DataFrame(data1)


# Apply the extraction functions to each column and create new columns
df1[['pH_value', 'pH_description']] = df1['ph'].apply(extract_ph_info)
df1[['Hardness_value', 'Hardness_description']] = df1['Hardness'].apply(extract_hardness_info)
df1[['Solids_value', 'Solids_description']] = df1['Solids'].apply(extract_solids_info)
df1[['Turbidity_value', 'Turbidity_description']] = df1['Turbidity'].apply(extract_turbidity_info)

# Display the updated DataFrame
print(df1)
# Out:
#       Index                                                 ph  \
# 0     10000  <br>😒The observed pH value of  0.4583260930518...
# 1     10001  <br>😀The pH value observed is:  0.006163832801...
# 2     10002  <h2>😀The pH reading measures 0.682188913921691...
# 3     10003  <p>😀The observed pH value of  0.56282397372454...
# 4     10004  <h1>😇The pH reading measures 0.336142283595807...
# ...     ...                                                ...
# 4995  14995  <h2>😀The observed pH value of  0.6239939359130...
# 4996  14996  <p>😀The pH reading measures 0.7886902033415697...
# 4997  14997  <br>😇The observed pH value of  0.1814957015634...
# 4998  14998  <br>😇The pH reading measures 0.074331335960389...
# 4999  14999  <h2>😍The pH reading measures 0.582922252039877...
#
#                                                Hardness  \
# 0     <h1>😁The observed water hardness of  1.7903445...
# 1     <p>😁The observed water hardness of  2.37971669...
# ...

# %%
df1.drop(columns=["ph","Hardness","Solids","Turbidity"], inplace=True)

# %%
df1.head()
# Out:
#    Index  Chloramines   Sulfate  Conductivity  Organic_carbon  \
# 0  10000     1.540880  1.659576      2.156778        1.665096
# 1  10001     1.225821  1.320635      2.251759        1.333259
# 2  10002     2.430112  1.178618      1.614353        0.890702
# 3  10003     1.910825  2.731592      1.626107        0.711949
# 4  10004     1.940168  1.269851      1.832447        0.947763
#
#    Trihalomethanes  pH_value pH_description  Hardness_value  \
# 0         2.105437  0.458326              0        1.790345
# 1         1.480757  0.006164              2        2.379717
# 2         1.824291  0.682189              2        1.408028
# 3         2.598104  0.562824              0        1.836970
# 4         1.052021  0.336142              2        1.510495
#
#   Hardness_description  Solids_value Solids_description  Turbidity_value  \
# 0                    0      1.573929                  1         0.980957
# 1                    0      1.381182                  3         1.502542
# ...

# %%
# Features and target
X = df.drop(columns=["Potability"])
y = df["Potability"]
X_test = df1.drop(columns=["Index"])

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
test_scaled = scaler.transform(X_test)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
pip install xgboost
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    - -------------------------------------- 3.1/124.9 MB 20.5 MB/s eta 0:00:06
#    - -------------------------------------- 6.0/124.9 MB 15.4 MB/s eta 0:00:08
#    -- ------------------------------------- 8.4/124.9 MB 14.1 MB/s eta 0:00:09
#    --- ------------------------------------ 11.0/124.9 MB 13.5 MB/s eta 0:00:09
#    ---- ----------------------------------- 13.9/124.9 MB 13.4 MB/s eta 0:00:09
#    ----- ---------------------------------- 16.5/124.9 MB 13.3 MB/s eta 0:00:09
#    ------ --------------------------------- 19.1/124.9 MB 13.1 MB/s eta 0:00:09
#    ------ --------------------------------- 21.8/124.9 MB 13.1 MB/s eta 0:00:08
#    ------- -------------------------------- 24.1/124.9 MB 13.0 MB/s eta 0:00:08
#    -------- ------------------------------- 26.7/124.9 MB 12.9 MB/s eta 0:00:08
#    --------- ------------------------------ 29.4/124.9 MB 12.9 MB/s eta 0:00:08
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import median_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
# Model 1: Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_val)
rf_score = max(0, 100 * (1 - median_absolute_error(y_val, rf_pred)))
print(f'Random Forest Model Score: {rf_score}')
# Out:
# Random Forest Model Score: 84.88028551619364

# %%
# Model 2: XGBoost Regressor
xgb_model = xgb.XGBRegressor(random_state=42)
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_val)
xgb_score = max(0, 100 * (1 - median_absolute_error(y_val, xgb_pred)))
print(f'XGBoost Model Score: {xgb_score}')
# Out:
# XGBoost Model Score: 85.14183111656058
